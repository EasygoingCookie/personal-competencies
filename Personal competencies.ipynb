# %% [markdown]
# # Личностные компетенции

# %% [markdown]
# На 516 наблюдений: 465 хороших оценки, 51 плохая (меньше 10 процентов)

# %% [markdown]
# 63 единичных наблюдения из 86 (по сути бесполезных)

# %% [markdown]
# # Общая коррелограмма

# %%
plt.figure(figsize=(10,10), dpi= 60)
sns.heatmap(binar_datasets.corr(), xticklabels=binar_datasets.corr().columns, yticklabels=binar_datasets.corr().columns, cmap='RdYlGn', center=0, annot=True)

# Decorations
plt.title('Correlogram of features', fontsize=22)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %% [markdown]
# # Выявление влиятельных личностных признаков

# %% [markdown]
# ### Влияние и важность признаков по методу Шепли

# %%
shap_values = explainer.shap_values(train)
shap.summary_plot(shap_values, train, feature_names)

# %% [markdown]
# ### Коэффициент Гилфорда

# %%
guilford
# Out:
#                       Компетенция  Коэффициент Гилфорда
# 0            ЛК: Добросовестность              0.230526
# 1   ЛК: Нацеленность на результат              0.298477
# 2                  ЛК: Открытость              0.279915
# 3      ЛК: Познавательный интерес              0.311879
# 4              ЛК: Сотрудничество              0.139275
# 5  ЛК: Эмоциональная стабильность             -0.038226
